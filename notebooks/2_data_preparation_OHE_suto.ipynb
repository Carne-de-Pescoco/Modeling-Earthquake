# %%
import os

import pandas as pd
import numpy as np

from category_encoders import TargetEncoder
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler
from feature_engine import categorical_encoders as ce

from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import RFE

import matplotlib.pyplot as plt
import seaborn as sns

os.chdir("../src/")
from utils.data_describe import DataDescribe as dd

basepath = "../data/external/"
path_x_train = "../data/external/train_values.csv"
path_y_train = "../data/external/train_labels.csv"
path_x_test = "../data/external/test_values.csv"

path_x_selected = "../data/interim/"
path_processed = "../data/processed/"

# Configurações para mostrar todas as colunas no iPython
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

# %%
# List all files in a directory using scandir()
print("-"*30)
print("Arquivos em data/external:\n")
with os.scandir(basepath) as entries:
    for entry in entries:
        if entry.is_file():
            print(entry.name)

print("-"*30)
print("Arquivos em data/interim:\n")

with os.scandir(path_x_selected) as entries:
    for entry in entries:
        if entry.is_file():
            print(entry.name)
print("-"*30)
# Out:
# ------------------------------
# Arquivos em data/external:
#
# submission_format.csv
# train_values.csv
# test_values.csv
# train_labels.csv
# .gitkeep
# ------------------------------
# Arquivos em data/interim:
#
# .gitkeep
# lst_X_train_booleanas.csv
# lst_X_train_categoricas.csv
# lst_X_train_continuas.csv
# lst_X_train_categoricas_ordinais.csv
# lst_X_train_categoricas_nominais.csv
# ------------------------------

# %% [markdown]
# # Início da preparação
#
# A preparação de dados inicial será:
# 1. One hot encoding dos categóricos nominais;
# 1. Standard scaling de todos os atributos.

# %%
# Carregando dados de treino
X_train = pd.read_csv(path_x_train, index_col=0)
y_train = pd.read_csv(path_y_train, index_col=0)

# Resgatando lista de atributos booleanos e categóricos.
lst_features_target_encoding = pd.read_csv(path_x_selected+"lst_X_train_categoricas_nominais.csv", index_col=0)
lst_features_target_encoding = list(lst_features_target_encoding["0"].unique())

# %% [markdown]
# ## Aplicando o one hot encoding nos atributos categóricos nominais

# %%
ohe_hot_encoder = ce.OneHotCategoricalEncoder(top_categories=None,
                                              variables=lst_features_target_encoding,
                                              drop_last=True)

ohe_hot_encoder.fit(X_train)

X_train_target_encoding = ohe_hot_encoder.transform(X_train)

# Criando lista com colunas que passaram pelo OHE:
lst_ohe_encoded_columns = []
for item in lst_features_target_encoding:
    lst_ohe_encoded_columns.extend([coluna for coluna in X_train_target_encoding.columns if item in coluna])

X_train_target_encoding[lst_ohe_encoded_columns].head()
# Out:
#              land_surface_condition_t  land_surface_condition_o  roof_type_n  \
# building_id
# 802906                              1                         0            1
# 28830                               0                         1            1
# 94947                               1                         0            1
# 590882                              1                         0            1
# 201944                              1                         0            1
#
#              roof_type_q  legal_ownership_status_v  legal_ownership_status_a  \
# building_id
# 802906                 0                         1                         0
# 28830                  0                         1                         0
# 94947                  0                         1                         0
# 590882                 0                         1                         0
# 201944                 0                         1                         0
#
#              legal_ownership_status_r  other_floor_type_q  other_floor_type_x  \
# building_id
# 802906                              0                   1                   0
# 28830                               0                   1                   0
# 94947                               0                   0                   1
# 590882                              0                   0                   1
# 201944                              0                   0                   1
#
#              other_floor_type_j  position_t  position_s  position_j  \
# building_id
# 802906                        0           1           0           0
# 28830                         0           0           1           0
# 94947                         0           1           0           0
# 590882                        0           0           1           0
# 201944                        0           0           1           0
#
#              foundation_type_r  foundation_type_w  foundation_type_i  \
# building_id
# 802906                       1                  0                  0
# 28830                        1                  0                  0
# 94947                        1                  0                  0
# 590882                       1                  0                  0
# 201944                       1                  0                  0
#
#              foundation_type_u  ground_floor_type_f  ground_floor_type_x  \
# building_id
# 802906                       0                    1                    0
# 28830                        0                    0                    1
# 94947                        0                    1                    0
# 590882                       0                    1                    0
# 201944                       0                    1                    0
#
#              ground_floor_type_v  ground_floor_type_z  plan_configuration_d  \
# building_id
# 802906                         0                    0                     1
# 28830                          0                    0                     1
# 94947                          0                    0                     1
# 590882                         0                    0                     1
# 201944                         0                    0                     1
#
#              plan_configuration_u  plan_configuration_s  plan_configuration_q  \
# building_id
# 802906                          0                     0                     0
# 28830                           0                     0                     0
# 94947                           0                     0                     0
# 590882                          0                     0                     0
# 201944                          0                     0                     0
#
#              plan_configuration_m  plan_configuration_c  plan_configuration_a  \
# building_id
# 802906                          0                     0                     0
# 28830                           0                     0                     0
# 94947                           0                     0                     0
# 590882                          0                     0                     0
# 201944                          0                     0                     0
#
#              plan_configuration_n  plan_configuration_f
# building_id
# 802906                          0                     0
# 28830                           0                     0
# 94947                           0                     0
# 590882                          0                     0
# 201944                          0                     0

# %% [markdown]
# ## Aplicando Standard Scaler sobre todos os atributos

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train_target_encoding)

X_train_scaled = pd.DataFrame(data=X_train_scaled, columns=X_train_target_encoding.columns, index=X_train_target_encoding.index)

# %% [markdown]
# # Dataframe para alimentar o modelo

# %%
df_train = pd.concat([X_train_scaled, y_train], axis=1)

df_train.to_parquet(path_processed+"df_train.pqt")

df_train.head()
# Out:
#              geo_level_1_id  geo_level_2_id  geo_level_3_id  \
# building_id
# 802906            -0.983414       -0.518705        1.629055
# 28830             -0.734459        0.481998       -0.945017
# 94947              0.883744       -0.819158        0.744612
# 590882             1.008221       -0.685893        1.216589
# 201944            -0.361028       -1.381296       -1.308119
#
#              count_floors_pre_eq       age  area_percentage  \
# building_id
# 802906                 -0.178274  0.047100        -0.459460
# 28830                  -0.178274 -0.224765        -0.004110
# 94947                  -0.178274 -0.224765        -0.687135
# 590882                 -0.178274 -0.224765        -0.459460
# 201944                  1.195989  0.047100        -0.004110
#
#              height_percentage  has_superstructure_adobe_mud  \
# building_id
# 802906               -0.226419                      3.206391
# 28830                 0.816109                     -0.311877
# 94947                -0.226419                     -0.311877
# 590882               -0.226419                     -0.311877
# 201944                1.858636                      3.206391
#
#              has_superstructure_mud_mortar_stone  \
# building_id
# 802906                                  0.558971
# 28830                                   0.558971
# 94947                                   0.558971
# 590882                                  0.558971
# 201944                                 -1.789003
#
#              has_superstructure_stone_flag  \
# building_id
# 802906                           -0.188554
# 28830                            -0.188554
# 94947                            -0.188554
# 590882                           -0.188554
# 201944                           -0.188554
#
#              has_superstructure_cement_mortar_stone  \
# building_id
# 802906                                    -0.136284
# 28830                                     -0.136284
# 94947                                     -0.136284
# 590882                                    -0.136284
# 201944                                    -0.136284
#
#              has_superstructure_mud_mortar_brick  \
# building_id
# 802906                                 -0.270442
# 28830                                  -0.270442
# 94947                                  -0.270442
# 590882                                 -0.270442
# 201944                                 -0.270442
#
#              has_superstructure_cement_mortar_brick  \
# building_id
# 802906                                    -0.285298
# 28830                                     -0.285298
# 94947                                     -0.285298
# 590882                                    -0.285298
# 201944                                    -0.285298
#
#              has_superstructure_timber  has_superstructure_bamboo  \
# building_id
# 802906                       -0.585029                  -0.304811
# 28830                        -0.585029                  -0.304811
# 94947                        -0.585029                  -0.304811
# 590882                        1.709316                   3.280725
# 201944                       -0.585029                  -0.304811
#
#              has_superstructure_rc_non_engineered  \
# building_id
# 802906                                  -0.210914
# 28830                                   -0.210914
# 94947                                   -0.210914
# 590882                                  -0.210914
# 201944                                  -0.210914
#
#              has_superstructure_rc_engineered  has_superstructure_other  \
# building_id
# 802906                              -0.126945                 -0.123339
# 28830                               -0.126945                 -0.123339
# 94947                               -0.126945                 -0.123339
# 590882                              -0.126945                 -0.123339
# 201944                              -0.126945                 -0.123339
#
#              count_families  has_secondary_use  has_secondary_use_agriculture  \
# building_id
# 802906             0.038365          -0.354928                      -0.262312
# 28830              0.038365          -0.354928                      -0.262312
# 94947              0.038365          -0.354928                      -0.262312
# 590882             0.038365          -0.354928                      -0.262312
# 201944             0.038365          -0.354928                      -0.262312
#
#              has_secondary_use_hotel  has_secondary_use_rental  \
# building_id
# 802906                     -0.186537                  -0.09037
# 28830                      -0.186537                  -0.09037
# 94947                      -0.186537                  -0.09037
# 590882                     -0.186537                  -0.09037
# 201944                     -0.186537                  -0.09037
#
#              has_secondary_use_institution  has_secondary_use_school  \
# building_id
# 802906                           -0.030676                 -0.018996
# 28830                            -0.030676                 -0.018996
# 94947                            -0.030676                 -0.018996
# 590882                           -0.030676                 -0.018996
# 201944                           -0.030676                 -0.018996
#
#              has_secondary_use_industry  has_secondary_use_health_post  \
# building_id
# 802906                        -0.032738                      -0.013714
# 28830                         -0.032738                      -0.013714
# 94947                         -0.032738                      -0.013714
# 590882                        -0.032738                      -0.013714
# 201944                        -0.032738                      -0.013714
#
#              has_secondary_use_gov_office  has_secondary_use_use_police  \
# building_id
# 802906                          -0.012076                     -0.009395
# 28830                           -0.012076                     -0.009395
# 94947                           -0.012076                     -0.009395
# 590882                          -0.012076                     -0.009395
# 201944                          -0.012076                     -0.009395
#
#              has_secondary_use_other  land_surface_condition_t  \
# building_id
# 802906                     -0.071731                  0.449747
# 28830                      -0.071731                 -2.223471
# 94947                      -0.071731                  0.449747
# 590882                     -0.071731                  0.449747
# 201944                     -0.071731                  0.449747
#
#              land_surface_condition_o  roof_type_n  roof_type_q  \
# building_id
# 802906                      -0.181556     0.652135    -0.556227
# 28830                        5.507931     0.652135    -0.556227
# 94947                       -0.181556     0.652135    -0.556227
# 590882                      -0.181556     0.652135    -0.556227
# 201944                      -0.181556     0.652135    -0.556227
#
#              legal_ownership_status_v  legal_ownership_status_a  \
# building_id
# 802906                       0.196223                 -0.146997
# 28830                        0.196223                 -0.146997
# 94947                        0.196223                 -0.146997
# 590882                       0.196223                 -0.146997
# 201944                       0.196223                 -0.146997
#
#              legal_ownership_status_r  other_floor_type_q  other_floor_type_x  \
# building_id
# 802906                      -0.075395            0.759411           -0.447303
# 28830                       -0.075395            0.759411           -0.447303
# 94947                       -0.075395           -1.316810            2.235620
# 590882                      -0.075395           -1.316810            2.235620
# 201944                      -0.075395           -1.316810            2.235620
#
#              other_floor_type_j  position_t  position_s  position_j  \
# building_id
# 802906                -0.424833    2.252816   -1.858462   -0.231741
# 28830                 -0.424833   -0.443889    0.538079   -0.231741
# 94947                 -0.424833    2.252816   -1.858462   -0.231741
# 590882                -0.424833   -0.443889    0.538079   -0.231741
# 201944                -0.424833   -0.443889    0.538079   -0.231741
#
#              foundation_type_r  foundation_type_w  foundation_type_i  \
# building_id
# 802906                 0.43462          -0.248163          -0.205699
# 28830                  0.43462          -0.248163          -0.205699
# 94947                  0.43462          -0.248163          -0.205699
# 590882                 0.43462          -0.248163          -0.205699
# 201944                 0.43462          -0.248163          -0.205699
#
#              foundation_type_u  ground_floor_type_f  ground_floor_type_x  \
# building_id
# 802906               -0.240598             0.493166            -0.324861
# 28830                -0.240598            -2.027715             3.078243
# 94947                -0.240598             0.493166            -0.324861
# 590882               -0.240598             0.493166            -0.324861
# 201944               -0.240598             0.493166            -0.324861
#
#              ground_floor_type_v  ground_floor_type_z  plan_configuration_d  \
# building_id
# 802906                 -0.322807            -0.062189              0.205192
# 28830                  -0.322807            -0.062189              0.205192
# 94947                  -0.322807            -0.062189              0.205192
# 590882                 -0.322807            -0.062189              0.205192
# 201944                 -0.322807            -0.062189              0.205192
#
#              plan_configuration_u  plan_configuration_s  plan_configuration_q  \
# building_id
# 802906                  -0.119168             -0.036462             -0.149431
# 28830                   -0.119168             -0.036462             -0.149431
# 94947                   -0.119168             -0.036462             -0.149431
# 590882                  -0.119168             -0.036462             -0.149431
# 201944                  -0.119168             -0.036462             -0.149431
#
#              plan_configuration_m  plan_configuration_c  plan_configuration_a  \
# building_id
# 802906                  -0.013287             -0.035337             -0.031112
# 28830                   -0.013287             -0.035337             -0.031112
# 94947                   -0.013287             -0.035337             -0.031112
# 590882                  -0.013287             -0.035337             -0.031112
# 201944                  -0.013287             -0.035337             -0.031112
#
#              plan_configuration_n  plan_configuration_f  damage_grade
# building_id
# 802906                  -0.012076             -0.009188             3
# 28830                   -0.012076             -0.009188             2
# 94947                   -0.012076             -0.009188             3
# 590882                  -0.012076             -0.009188             2
# 201944                  -0.012076             -0.009188             3

# %%
# Armazenando ordem dos atributos:
lst_features_train = df_train.columns.tolist()
lst_features_train.pop()
# Out:
# 'damage_grade'

# %% [markdown]
# # Aplicando os encoders treinados no dataset de teste

# %%
X_test = pd.read_csv(path_x_test, index_col=0)
X_test.head()
# Out:
#              geo_level_1_id  geo_level_2_id  geo_level_3_id  \
# building_id
# 300051                   17             596           11307
# 99355                     6             141           11987
# 890251                   22              19           10044
# 745817                   26              39             633
# 421793                   17             289            7970
#
#              count_floors_pre_eq  age  area_percentage  height_percentage  \
# building_id
# 300051                         3   20                7                  6
# 99355                          2   25               13                  5
# 890251                         2    5                4                  5
# 745817                         1    0               19                  3
# 421793                         3   15                8                  7
#
#             land_surface_condition foundation_type roof_type  \
# building_id
# 300051                           t               r         n
# 99355                            t               r         n
# 890251                           t               r         n
# 745817                           t               r         x
# 421793                           t               r         q
#
#             ground_floor_type other_floor_type position plan_configuration  \
# building_id
# 300051                      f                q        s                  d
# 99355                       f                q        s                  d
# 890251                      f                q        s                  d
# 745817                      v                j        t                  d
# 421793                      f                q        t                  d
#
#              has_superstructure_adobe_mud  \
# building_id
# 300051                                  0
# 99355                                   0
# 890251                                  0
# 745817                                  0
# 421793                                  0
#
#              has_superstructure_mud_mortar_stone  \
# building_id
# 300051                                         1
# 99355                                          1
# 890251                                         1
# 745817                                         0
# 421793                                         1
#
#              has_superstructure_stone_flag  \
# building_id
# 300051                                   0
# 99355                                    0
# 890251                                   0
# 745817                                   0
# 421793                                   0
#
#              has_superstructure_cement_mortar_stone  \
# building_id
# 300051                                            0
# 99355                                             0
# 890251                                            0
# 745817                                            0
# 421793                                            0
#
#              has_superstructure_mud_mortar_brick  \
# building_id
# 300051                                         0
# 99355                                          0
# 890251                                         0
# 745817                                         0
# 421793                                         0
#
#              has_superstructure_cement_mortar_brick  \
# building_id
# 300051                                            0
# 99355                                             0
# 890251                                            0
# 745817                                            1
# 421793                                            0
#
#              has_superstructure_timber  has_superstructure_bamboo  \
# building_id
# 300051                               0                          0
# 99355                                0                          0
# 890251                               0                          0
# 745817                               0                          0
# 421793                               0                          0
#
#              has_superstructure_rc_non_engineered  \
# building_id
# 300051                                          0
# 99355                                           0
# 890251                                          0
# 745817                                          0
# 421793                                          0
#
#              has_superstructure_rc_engineered  has_superstructure_other  \
# building_id
# 300051                                      0                         0
# 99355                                       0                         0
# 890251                                      0                         0
# 745817                                      0                         0
# 421793                                      0                         0
#
#             legal_ownership_status  count_families  has_secondary_use  \
# building_id
# 300051                           v               1                  0
# 99355                            v               1                  1
# 890251                           v               1                  0
# 745817                           v               2                  1
# 421793                           v               1                  0
#
#              has_secondary_use_agriculture  has_secondary_use_hotel  \
# building_id
# 300051                                   0                        0
# 99355                                    1                        0
# 890251                                   0                        0
# 745817                                   0                        0
# 421793                                   0                        0
#
#              has_secondary_use_rental  has_secondary_use_institution  \
# building_id
# 300051                              0                              0
# 99355                               0                              0
# 890251                              0                              0
# 745817                              1                              0
# 421793                              0                              0
#
#              has_secondary_use_school  has_secondary_use_industry  \
# building_id
# 300051                              0                           0
# 99355                               0                           0
# 890251                              0                           0
# 745817                              0                           0
# 421793                              0                           0
#
#              has_secondary_use_health_post  has_secondary_use_gov_office  \
# building_id
# 300051                                   0                             0
# 99355                                    0                             0
# 890251                                   0                             0
# 745817                                   0                             0
# 421793                                   0                             0
#
#              has_secondary_use_use_police  has_secondary_use_other
# building_id
# 300051                                  0                        0
# 99355                                   0                        0
# 890251                                  0                        0
# 745817                                  0                        0
# 421793                                  0                        0

# %%
X_test_encoded = X_test.copy()

X_test_encoded = ohe_hot_encoder.transform(X_test_encoded)
X_test_encoded_scaled = scaler.transform(X_test_encoded)

X_test_encoded_scaled = pd.DataFrame(data=X_test_encoded, columns=X_test_encoded.columns, index=X_test_encoded.index)
X_test_encoded_scaled = X_test_encoded_scaled[lst_features_train]

# %%
X_test_encoded.to_parquet(path_processed+"X_test_encoded.pqt")
