# %%
import os

import pandas as pd
import numpy as np

from category_encoders import TargetEncoder
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler
from feature_engine import categorical_encoders as ce

from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import RFE

import matplotlib.pyplot as plt
import seaborn as sns

os.chdir("../src/")
from utils.data_describe import DataDescribe as dd

basepath = "../data/external/"
path_x_train = "../data/external/train_values.csv"
path_y_train = "../data/external/train_labels.csv"
path_x_test = "../data/external/test_values.csv"

path_x_selected = "../data/interim/"
path_processed = "../data/processed/"

# Configurações para mostrar todas as colunas no iPython
# pd.set_option('display.max_rows', 50)
pd.set_option('display.max_columns', None)
# pd.set_option('display.width', None)
# pd.set_option('display.max_colwidth', None)

# %%
# List all files in a directory using scandir()
print("-"*30)
print("Arquivos em data/external:\n")
with os.scandir(basepath) as entries:
    for entry in entries:
        if entry.is_file():
            print(entry.name)

print("-"*30)
print("Arquivos em data/interim:\n")

with os.scandir(path_x_selected) as entries:
    for entry in entries:
        if entry.is_file():
            print(entry.name)
print("-"*30)
# Out:
# ------------------------------
# Arquivos em data/external:
#
# .gitkeep
# submission_format.csv
# test_values.csv
# train_labels.csv
# train_values.csv
# ------------------------------
# Arquivos em data/interim:
#
# .gitkeep
# lst_X_train_booleanas.csv
# lst_X_train_categoricas.csv
# lst_X_train_categoricas_nominais.csv
# lst_X_train_categoricas_ordinais.csv
# lst_X_train_continuas.csv
# lst_selected_features.csv
# ------------------------------

# %% [markdown]
# # Início da preparação
#
# A preparação de dados inicial será:
# 1. One hot encoding dos categóricos nominais;
# 1. Standard scaling de todos os atributos.

# %%
# Carregando dados de treino
lst_selected_features = pd.read_csv(path_x_selected+"lst_selected_features.csv", index_col=0)
lst_selected_features = list(lst_selected_features["0"].unique())

X_train = pd.read_csv(path_x_train, index_col=0)
X_train = X_train[lst_selected_features]

y_train = pd.read_csv(path_y_train, index_col=0)

X_test = pd.read_csv(path_x_test, index_col=0)
X_test = X_test[lst_selected_features]

# %%
# Resgatando lista de atributos booleanos e categóricos.
lst_features_rare_label_encoding = pd.read_csv(path_x_selected+"lst_X_train_categoricas_ordinais.csv", index_col=0)
lst_features_rare_label_encoding = list(lst_features_rare_label_encoding["0"].unique())

lst_features_target_encoding = pd.read_csv(path_x_selected+"lst_X_train_categoricas_nominais.csv", index_col=0)
lst_features_target_encoding = list(lst_features_target_encoding["0"].unique())

print(f"""Atributos categóricos ordinais que passarão pelo Rare Label Encoding e posteriormente pelo One Hot Encoding:
{lst_features_rare_label_encoding}

Atributos categóricos nominais que passarão somente por One Hot Encoding:
{lst_features_target_encoding}
""")
# Out:
# Atributos categóricos ordinais que passarão pelo Rare Label Encoding e posteriormente pelo One Hot Encoding:
# ['count_floors_pre_eq', 'count_families']
#
# Atributos categóricos nominais que passarão somente por One Hot Encoding:
# ['land_surface_condition', 'roof_type', 'legal_ownership_status', 'other_floor_type', 'position', 'foundation_type', 'ground_floor_type', 'plan_configuration']

# %% [markdown]
# ## Aplicando o Rare Label Encoding nos atributos categóricos ordinais

# %%
# Essa célula, apenans transforma todas as classes dos atributos categoricos ordinais em números inteiros e troca o label 'Rare' para o próximo número inteiro da lista.

def transform_rare_int(df, lst_colunas):
    dct_features = {}

    for feature in lst_colunas:
        lst_features = sorted(df[feature].unique())
        dct_features[feature] = {}
        for feature_in in lst_features:
            if 'Rare' in feature_in:
                dct_features[feature][feature_in] = int(max(dct_features[feature]))+1
            else:
                dct_features[feature][feature_in] = int(feature_in)
        df[feature].replace(dct_features[feature], inplace=True)

    return df

# %%
for coluna in X_train[lst_features_rare_label_encoding].columns:
    X_train.loc[:, coluna] = X_train.loc[:, coluna].astype(str)

rare_label_encoder = ce.RareLabelCategoricalEncoder(tol=0.025, n_categories=5,
                                         variables=lst_features_rare_label_encoding,
                                         replace_with='Rare')

X_train = rare_label_encoder.fit_transform(X_train)

X_train = transform_rare_int(X_train, lst_features_rare_label_encoding)

X_train[lst_features_rare_label_encoding].head()
# Out:
#              count_floors_pre_eq  count_families
# building_id
# 802906                         2               1
# 28830                          2               1
# 94947                          2               1
# 590882                         2               1
# 201944                         3               1

# %% [markdown]
# ## Aplicando o one hot encoding nos atributos categóricos nominais e ordinais

# %%
# Adicionando os atributos que passaram pelo Rare Label Encoding:
lst_features_target_encoding.extend(lst_features_rare_label_encoding)
lst_features_target_encoding = list(set(lst_features_target_encoding))

ohe_hot_encoder = ce.OneHotCategoricalEncoder(top_categories=None,
                                              variables=lst_features_target_encoding,
                                              drop_last=True)

ohe_hot_encoder.fit(X_train)

X_train_target_encoding = ohe_hot_encoder.transform(X_train)

# Criando lista com colunas que passaram pelo OHE:
lst_ohe_encoded_columns = []
for item in lst_features_target_encoding:
    lst_ohe_encoded_columns.extend([coluna for coluna in X_train_target_encoding.columns if item in coluna])

X_train_target_encoding[lst_ohe_encoded_columns].head()
# Out:
#              other_floor_type_q  other_floor_type_x  other_floor_type_j  \
# building_id
# 802906                        1                   0                   0
# 28830                         1                   0                   0
# 94947                         0                   1                   0
# 590882                        0                   1                   0
# 201944                        0                   1                   0
#
#              count_floors_pre_eq_2  count_floors_pre_eq_3  \
# building_id
# 802906                           1                      0
# 28830                            1                      0
# 94947                            1                      0
# 590882                           1                      0
# 201944                           0                      1
#
#              count_floors_pre_eq_1  roof_type_n  roof_type_q  position_t  \
# building_id
# 802906                           0            1            0           1
# 28830                            0            1            0           0
# 94947                            0            1            0           1
# 590882                           0            1            0           0
# 201944                           0            1            0           0
#
#              position_s  position_j  count_families_1  count_families_0  \
# building_id
# 802906                0           0                 1                 0
# 28830                 1           0                 1                 0
# 94947                 0           0                 1                 0
# 590882                1           0                 1                 0
# 201944                1           0                 1                 0
#
#              count_families_2  plan_configuration_d  plan_configuration_u  \
# building_id
# 802906                      0                     1                     0
# 28830                       0                     1                     0
# 94947                       0                     1                     0
# 590882                      0                     1                     0
# 201944                      0                     1                     0
#
#              plan_configuration_s  plan_configuration_q  plan_configuration_m  \
# building_id
# 802906                          0                     0                     0
# 28830                           0                     0                     0
# 94947                           0                     0                     0
# 590882                          0                     0                     0
# 201944                          0                     0                     0
#
#              plan_configuration_c  plan_configuration_a  plan_configuration_n  \
# building_id
# 802906                          0                     0                     0
# 28830                           0                     0                     0
# 94947                           0                     0                     0
# 590882                          0                     0                     0
# 201944                          0                     0                     0
#
#              plan_configuration_f  legal_ownership_status_v  \
# building_id
# 802906                          0                         1
# 28830                           0                         1
# 94947                           0                         1
# 590882                          0                         1
# 201944                          0                         1
#
#              legal_ownership_status_a  legal_ownership_status_r  \
# building_id
# 802906                              0                         0
# 28830                               0                         0
# 94947                               0                         0
# 590882                              0                         0
# 201944                              0                         0
#
#              land_surface_condition_t  land_surface_condition_o  \
# building_id
# 802906                              1                         0
# 28830                               0                         1
# 94947                               1                         0
# 590882                              1                         0
# 201944                              1                         0
#
#              ground_floor_type_f  ground_floor_type_x  ground_floor_type_v  \
# building_id
# 802906                         1                    0                    0
# 28830                          0                    1                    0
# 94947                          1                    0                    0
# 590882                         1                    0                    0
# 201944                         1                    0                    0
#
#              ground_floor_type_z  foundation_type_r  foundation_type_w  \
# building_id
# 802906                         0                  1                  0
# 28830                          0                  1                  0
# 94947                          0                  1                  0
# 590882                         0                  1                  0
# 201944                         0                  1                  0
#
#              foundation_type_i  foundation_type_u
# building_id
# 802906                       0                  0
# 28830                        0                  0
# 94947                        0                  0
# 590882                       0                  0
# 201944                       0                  0

# %%
# Adicionando os atributos que passaram pelo Rare Label Encoding:
# lst_features_target_encoding.extend(lst_features_rare_label_encoding)
# lst_features_target_encoding = list(set(lst_features_target_encoding))

ohe_hot_encoder = ce.OneHotCategoricalEncoder(top_categories=None,
                                              variables=lst_features_target_encoding,
                                              drop_last=True)

ohe_hot_encoder.fit(X_train)

X_train_target_encoding = ohe_hot_encoder.transform(X_train)

# Criando lista com colunas que passaram pelo OHE:
lst_ohe_encoded_columns = []
for item in lst_features_target_encoding:
    lst_ohe_encoded_columns.extend([coluna for coluna in X_train_target_encoding.columns if item in coluna])

X_train_target_encoding[lst_ohe_encoded_columns].head()
# Out:
#              land_surface_condition_t  land_surface_condition_o  roof_type_n  \
# building_id
# 802906                              1                         0            1
# 28830                               0                         1            1
# 94947                               1                         0            1
# 590882                              1                         0            1
# 201944                              1                         0            1
#
#              roof_type_q  legal_ownership_status_v  legal_ownership_status_a  \
# building_id
# 802906                 0                         1                         0
# 28830                  0                         1                         0
# 94947                  0                         1                         0
# 590882                 0                         1                         0
# 201944                 0                         1                         0
#
#              legal_ownership_status_r  other_floor_type_q  other_floor_type_x  \
# building_id
# 802906                              0                   1                   0
# 28830                               0                   1                   0
# 94947                               0                   0                   1
# 590882                              0                   0                   1
# 201944                              0                   0                   1
#
#              other_floor_type_j  position_t  position_s  position_j  \
# building_id
# 802906                        0           1           0           0
# 28830                         0           0           1           0
# 94947                         0           1           0           0
# 590882                        0           0           1           0
# 201944                        0           0           1           0
#
#              foundation_type_r  foundation_type_w  foundation_type_i  \
# building_id
# 802906                       1                  0                  0
# 28830                        1                  0                  0
# 94947                        1                  0                  0
# 590882                       1                  0                  0
# 201944                       1                  0                  0
#
#              foundation_type_u  ground_floor_type_f  ground_floor_type_x  \
# building_id
# 802906                       0                    1                    0
# 28830                        0                    0                    1
# 94947                        0                    1                    0
# 590882                       0                    1                    0
# 201944                       0                    1                    0
#
#              ground_floor_type_v  ground_floor_type_z  plan_configuration_d  \
# building_id
# 802906                         0                    0                     1
# 28830                          0                    0                     1
# 94947                          0                    0                     1
# 590882                         0                    0                     1
# 201944                         0                    0                     1
#
#              plan_configuration_u  plan_configuration_s  plan_configuration_q  \
# building_id
# 802906                          0                     0                     0
# 28830                           0                     0                     0
# 94947                           0                     0                     0
# 590882                          0                     0                     0
# 201944                          0                     0                     0
#
#              plan_configuration_m  plan_configuration_c  plan_configuration_a  \
# building_id
# 802906                          0                     0                     0
# 28830                           0                     0                     0
# 94947                           0                     0                     0
# 590882                          0                     0                     0
# 201944                          0                     0                     0
#
#              plan_configuration_n  plan_configuration_f
# building_id
# 802906                          0                     0
# 28830                           0                     0
# 94947                           0                     0
# 590882                          0                     0
# 201944                          0                     0

# %% [markdown]
# ## Aplicando Standard Scaler sobre todos os atributos

# %%
lst_boolean_features = pd.read_csv(path_x_selected+"lst_X_train_booleanas.csv", index_col=0)
lst_boolean_features = list(lst_boolean_features["0"].unique())
# lst_boolean_features.extend(lst_ohe_encoded_columns)
# lst_boolean_features = list(set(lst_boolean_features))

# %%
X_train_target_scaling = X_train_target_encoding.drop(lst_boolean_features, axis=1)
X_train_target_scaling.head()
# Out:
#              count_families  area_percentage  age  geo_level_2_id  \
# building_id
# 802906                    1                6   30             487
# 28830                     1                8   10             900
# 94947                     1                5   10             363
# 590882                    1                6   10             418
# 201944                    1                8   30             131
#
#              geo_level_3_id  height_percentage  geo_level_1_id  \
# building_id
# 802906                12198                  5               6
# 28830                  2812                  7               8
# 94947                  8973                  5              21
# 590882                10694                  5              22
# 201944                 1488                  9              11
#
#              count_floors_pre_eq  land_surface_condition_t  \
# building_id
# 802906                         2                         1
# 28830                          2                         0
# 94947                          2                         1
# 590882                         2                         1
# 201944                         3                         1
#
#              land_surface_condition_o  roof_type_n  roof_type_q  \
# building_id
# 802906                              0            1            0
# 28830                               1            1            0
# 94947                               0            1            0
# 590882                              0            1            0
# 201944                              0            1            0
#
#              legal_ownership_status_v  legal_ownership_status_a  \
# building_id
# 802906                              1                         0
# 28830                               1                         0
# 94947                               1                         0
# 590882                              1                         0
# 201944                              1                         0
#
#              legal_ownership_status_r  other_floor_type_q  other_floor_type_x  \
# building_id
# 802906                              0                   1                   0
# 28830                               0                   1                   0
# 94947                               0                   0                   1
# 590882                              0                   0                   1
# 201944                              0                   0                   1
#
#              other_floor_type_j  position_t  position_s  position_j  \
# building_id
# 802906                        0           1           0           0
# 28830                         0           0           1           0
# 94947                         0           1           0           0
# 590882                        0           0           1           0
# 201944                        0           0           1           0
#
#              foundation_type_r  foundation_type_w  foundation_type_i  \
# building_id
# 802906                       1                  0                  0
# 28830                        1                  0                  0
# 94947                        1                  0                  0
# 590882                       1                  0                  0
# 201944                       1                  0                  0
#
#              foundation_type_u  ground_floor_type_f  ground_floor_type_x  \
# building_id
# 802906                       0                    1                    0
# 28830                        0                    0                    1
# 94947                        0                    1                    0
# 590882                       0                    1                    0
# 201944                       0                    1                    0
#
#              ground_floor_type_v  ground_floor_type_z  plan_configuration_d  \
# building_id
# 802906                         0                    0                     1
# 28830                          0                    0                     1
# 94947                          0                    0                     1
# 590882                         0                    0                     1
# 201944                         0                    0                     1
#
#              plan_configuration_u  plan_configuration_s  plan_configuration_q  \
# building_id
# 802906                          0                     0                     0
# 28830                           0                     0                     0
# 94947                           0                     0                     0
# 590882                          0                     0                     0
# 201944                          0                     0                     0
#
#              plan_configuration_m  plan_configuration_c  plan_configuration_a  \
# building_id
# 802906                          0                     0                     0
# 28830                           0                     0                     0
# 94947                           0                     0                     0
# 590882                          0                     0                     0
# 201944                          0                     0                     0
#
#              plan_configuration_n  plan_configuration_f
# building_id
# 802906                          0                     0
# 28830                           0                     0
# 94947                           0                     0
# 590882                          0                     0
# 201944                          0                     0

# %%
scaler = StandardScaler()
# X_train_scaled = scaler.fit_transform(X_train_target_scaling)
# X_train_scaled = pd.DataFrame(data=X_train_scaled, columns=X_train_target_scaling.columns, index=X_train_target_scaling.index)

X_train_scaled = X_train_target_scaling

# %% [markdown]
# # Dataframe para alimentar o modelo

# %%
# TEMPORÁRIO

X_train.shape
# Out:
# (260601, 38)

# %%
df_train = pd.concat([X_train_scaled, X_train_target_encoding[lst_boolean_features],y_train], axis=1)

df_train.to_parquet(path_processed+"df_train.pqt")

df_train.head()
# Out:
#              count_families  area_percentage  age  geo_level_2_id  \
# building_id
# 802906                    1                6   30             487
# 28830                     1                8   10             900
# 94947                     1                5   10             363
# 590882                    1                6   10             418
# 201944                    1                8   30             131
#
#              geo_level_3_id  height_percentage  geo_level_1_id  \
# building_id
# 802906                12198                  5               6
# 28830                  2812                  7               8
# 94947                  8973                  5              21
# 590882                10694                  5              22
# 201944                 1488                  9              11
#
#              count_floors_pre_eq  land_surface_condition_t  \
# building_id
# 802906                         2                         1
# 28830                          2                         0
# 94947                          2                         1
# 590882                         2                         1
# 201944                         3                         1
#
#              land_surface_condition_o  roof_type_n  roof_type_q  \
# building_id
# 802906                              0            1            0
# 28830                               1            1            0
# 94947                               0            1            0
# 590882                              0            1            0
# 201944                              0            1            0
#
#              legal_ownership_status_v  legal_ownership_status_a  \
# building_id
# 802906                              1                         0
# 28830                               1                         0
# 94947                               1                         0
# 590882                              1                         0
# 201944                              1                         0
#
#              legal_ownership_status_r  other_floor_type_q  other_floor_type_x  \
# building_id
# 802906                              0                   1                   0
# 28830                               0                   1                   0
# 94947                               0                   0                   1
# 590882                              0                   0                   1
# 201944                              0                   0                   1
#
#              other_floor_type_j  position_t  position_s  position_j  \
# building_id
# 802906                        0           1           0           0
# 28830                         0           0           1           0
# 94947                         0           1           0           0
# 590882                        0           0           1           0
# 201944                        0           0           1           0
#
#              foundation_type_r  foundation_type_w  foundation_type_i  \
# building_id
# 802906                       1                  0                  0
# 28830                        1                  0                  0
# 94947                        1                  0                  0
# 590882                       1                  0                  0
# 201944                       1                  0                  0
#
#              foundation_type_u  ground_floor_type_f  ground_floor_type_x  \
# building_id
# 802906                       0                    1                    0
# 28830                        0                    0                    1
# 94947                        0                    1                    0
# 590882                       0                    1                    0
# 201944                       0                    1                    0
#
#              ground_floor_type_v  ground_floor_type_z  plan_configuration_d  \
# building_id
# 802906                         0                    0                     1
# 28830                          0                    0                     1
# 94947                          0                    0                     1
# 590882                         0                    0                     1
# 201944                         0                    0                     1
#
#              plan_configuration_u  plan_configuration_s  plan_configuration_q  \
# building_id
# 802906                          0                     0                     0
# 28830                           0                     0                     0
# 94947                           0                     0                     0
# 590882                          0                     0                     0
# 201944                          0                     0                     0
#
#              plan_configuration_m  plan_configuration_c  plan_configuration_a  \
# building_id
# 802906                          0                     0                     0
# 28830                           0                     0                     0
# 94947                           0                     0                     0
# 590882                          0                     0                     0
# 201944                          0                     0                     0
#
#              plan_configuration_n  plan_configuration_f  \
# building_id
# 802906                          0                     0
# 28830                           0                     0
# 94947                           0                     0
# 590882                          0                     0
# 201944                          0                     0
#
#              has_superstructure_mud_mortar_stone  has_superstructure_timber  \
# building_id
# 802906                                         1                          0
# 28830                                          1                          0
# 94947                                          1                          0
# 590882                                         1                          1
# 201944                                         0                          0
#
#              has_secondary_use  has_superstructure_adobe_mud  \
# building_id
# 802906                       0                             1
# 28830                        0                             0
# 94947                        0                             0
# 590882                       0                             0
# 201944                       0                             1
#
#              has_superstructure_bamboo  \
# building_id
# 802906                               0
# 28830                                0
# 94947                                0
# 590882                               1
# 201944                               0
#
#              has_superstructure_cement_mortar_brick  \
# building_id
# 802906                                            0
# 28830                                             0
# 94947                                             0
# 590882                                            0
# 201944                                            0
#
#              has_superstructure_mud_mortar_brick  \
# building_id
# 802906                                         0
# 28830                                          0
# 94947                                          0
# 590882                                         0
# 201944                                         0
#
#              has_secondary_use_agriculture  \
# building_id
# 802906                                   0
# 28830                                    0
# 94947                                    0
# 590882                                   0
# 201944                                   0
#
#              has_superstructure_rc_non_engineered  \
# building_id
# 802906                                          0
# 28830                                           0
# 94947                                           0
# 590882                                          0
# 201944                                          0
#
#              has_superstructure_stone_flag  has_secondary_use_hotel  \
# building_id
# 802906                                   0                        0
# 28830                                    0                        0
# 94947                                    0                        0
# 590882                                   0                        0
# 201944                                   0                        0
#
#              has_superstructure_cement_mortar_stone  \
# building_id
# 802906                                            0
# 28830                                             0
# 94947                                             0
# 590882                                            0
# 201944                                            0
#
#              has_superstructure_rc_engineered  has_superstructure_other  \
# building_id
# 802906                                      0                         0
# 28830                                       0                         0
# 94947                                       0                         0
# 590882                                      0                         0
# 201944                                      0                         0
#
#              has_secondary_use_rental  has_secondary_use_other  \
# building_id
# 802906                              0                        0
# 28830                               0                        0
# 94947                               0                        0
# 590882                              0                        0
# 201944                              0                        0
#
#              has_secondary_use_industry  has_secondary_use_institution  \
# building_id
# 802906                                0                              0
# 28830                                 0                              0
# 94947                                 0                              0
# 590882                                0                              0
# 201944                                0                              0
#
#              has_secondary_use_school  has_secondary_use_health_post  \
# building_id
# 802906                              0                              0
# 28830                               0                              0
# 94947                               0                              0
# 590882                              0                              0
# 201944                              0                              0
#
#              has_secondary_use_gov_office  has_secondary_use_use_police  \
# building_id
# 802906                                  0                             0
# 28830                                   0                             0
# 94947                                   0                             0
# 590882                                  0                             0
# 201944                                  0                             0
#
#              damage_grade
# building_id
# 802906                  3
# 28830                   2
# 94947                   3
# 590882                  2
# 201944                  3

# %%
# Armazenando ordem dos atributos:
lst_features_train = df_train.columns.tolist()
lst_features_train.pop()
# Out:
# 'damage_grade'

# %% [markdown]
# # Aplicando os encoders treinados no dataset de teste

# %%
X_test.head()
# Out:
#              count_families  area_percentage  has_secondary_use_gov_office  \
# building_id
# 300051                    1                7                             0
# 99355                     1               13                             0
# 890251                    1                4                             0
# 745817                    2               19                             0
# 421793                    1                8                             0
#
#              has_superstructure_stone_flag  \
# building_id
# 300051                                   0
# 99355                                    0
# 890251                                   0
# 745817                                   0
# 421793                                   0
#
#              has_superstructure_mud_mortar_stone  \
# building_id
# 300051                                         1
# 99355                                          1
# 890251                                         1
# 745817                                         0
# 421793                                         1
#
#              has_superstructure_rc_engineered  has_secondary_use  \
# building_id
# 300051                                      0                  0
# 99355                                       0                  1
# 890251                                      0                  0
# 745817                                      0                  1
# 421793                                      0                  0
#
#              has_superstructure_mud_mortar_brick position  \
# building_id
# 300051                                         0        s
# 99355                                          0        s
# 890251                                         0        s
# 745817                                         0        t
# 421793                                         0        t
#
#             land_surface_condition  age  geo_level_2_id  geo_level_3_id  \
# building_id
# 300051                           t   20             596           11307
# 99355                            t   25             141           11987
# 890251                           t    5              19           10044
# 745817                           t    0              39             633
# 421793                           t   15             289            7970
#
#              height_percentage  has_secondary_use_industry plan_configuration  \
# building_id
# 300051                       6                           0                  d
# 99355                        5                           0                  d
# 890251                       5                           0                  d
# 745817                       3                           0                  d
# 421793                       7                           0                  d
#
#              has_secondary_use_health_post  has_secondary_use_hotel  \
# building_id
# 300051                                   0                        0
# 99355                                    0                        0
# 890251                                   0                        0
# 745817                                   0                        0
# 421793                                   0                        0
#
#              has_secondary_use_agriculture  has_superstructure_other  \
# building_id
# 300051                                   0                         0
# 99355                                    1                         0
# 890251                                   0                         0
# 745817                                   0                         0
# 421793                                   0                         0
#
#              has_superstructure_timber  has_secondary_use_other  \
# building_id
# 300051                               0                        0
# 99355                                0                        0
# 890251                               0                        0
# 745817                               0                        0
# 421793                               0                        0
#
#              has_superstructure_cement_mortar_brick  \
# building_id
# 300051                                            0
# 99355                                             0
# 890251                                            0
# 745817                                            1
# 421793                                            0
#
#              has_superstructure_cement_mortar_stone  has_secondary_use_rental  \
# building_id
# 300051                                            0                         0
# 99355                                             0                         0
# 890251                                            0                         0
# 745817                                            0                         1
# 421793                                            0                         0
#
#             foundation_type  has_superstructure_adobe_mud  geo_level_1_id  \
# building_id
# 300051                    r                             0              17
# 99355                     r                             0               6
# 890251                    r                             0              22
# 745817                    r                             0              26
# 421793                    r                             0              17
#
#              has_secondary_use_use_police  \
# building_id
# 300051                                  0
# 99355                                   0
# 890251                                  0
# 745817                                  0
# 421793                                  0
#
#              has_superstructure_rc_non_engineered  has_secondary_use_school  \
# building_id
# 300051                                          0                         0
# 99355                                           0                         0
# 890251                                          0                         0
# 745817                                          0                         0
# 421793                                          0                         0
#
#              count_floors_pre_eq ground_floor_type  \
# building_id
# 300051                         3                 f
# 99355                          2                 f
# 890251                         2                 f
# 745817                         1                 v
# 421793                         3                 f
#
#              has_secondary_use_institution roof_type  \
# building_id
# 300051                                   0         n
# 99355                                    0         n
# 890251                                   0         n
# 745817                                   0         x
# 421793                                   0         q
#
#              has_superstructure_bamboo legal_ownership_status other_floor_type
# building_id
# 300051                               0                      v                q
# 99355                                0                      v                q
# 890251                               0                      v                q
# 745817                               0                      v                j
# 421793                               0                      v                q

# %%
X_test_encoded = X_test.copy()

X_test_encoded = rare_label_encoder.transform(X_test_encoded)
X_test_encoded = transform_rare_int(X_test_encoded, lst_features_rare_label_encoding)
X_test_ohe_encoded = ohe_hot_encoder.transform(X_test_encoded)
# X_test_encoded_scaled = scaler.transform(X_test_ohe_encoded.drop(lst_boolean_features, axis=1))
X_test_encoded_scaled = X_test_ohe_encoded.drop(lst_boolean_features, axis=1)

columns_encoded_scaled = X_test_ohe_encoded.drop(lst_boolean_features, axis=1)
columns_encoded_scaled = columns_encoded_scaled.columns
index_encoded_scaled = X_test_encoded.index

X_test_ohe_encoded = X_test_ohe_encoded[lst_boolean_features].copy()

X_test_encoded_scaled = pd.DataFrame(data=X_test_encoded_scaled, columns=columns_encoded_scaled,
                                     index=index_encoded_scaled)

X_test_encoded_scaled = pd.concat([X_test_encoded_scaled, X_test_ohe_encoded], axis=1)

# %%
X_test_encoded_scaled.to_parquet(path_processed+"X_test_encoded.pqt")
